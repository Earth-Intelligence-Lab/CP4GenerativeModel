# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y1_reduce = np.load('/Users/qidongyang/Desktop/ensemble_CP/Mengze/y1_reduce_TP.npy')
y_hat1_reduce = np.load('/Users/qidongyang/Desktop/ensemble_CP/Mengze/y_hat1_reduce_TP.npy')

# %%
y1_reduce.shape
# Out:
# (3249, 30, 2)

# %%
for i in range(200):
    plt.scatter(y_hat1_reduce[i, :, 0], y_hat1_reduce[i, :, 1])
    plt.xlim(-0.5, 2)
    plt.ylim(-0.5, 2)
    plt.show()
